# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahale-Pradnesh/Data-Science-and-Machine-Learning/blob/main/YBI_Foundation_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import pandas as pd

# %%
# read data
diabetes= pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Diabetes.csv')

# %%
diabetes.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
# define target(y)  and features (x)

Y=diabetes['diabetes']
X=diabetes[['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]

# %%
# importing the train test split function
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,train_size=0.7,random_state=2529)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((537, 8), (231, 8), (537,), (231,))

# %%
X_train
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age
# 406            4      115         72        0        0  28.9  0.376   46
# 623            0       94         70       27      115  43.5  0.347   21
# 615            3      106         72        0        0  25.8  0.207   27
# 314            7      109         80       31        0  35.9  1.127   43
# 84             5      137        108        0        0  48.8  0.227   37
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 584            8      124         76       24      600  28.7  0.687   52
# 740           11      120         80       37      150  42.3  0.785   48
# 399            3      193         70       31        0  34.9  0.241   25
# 562            1       87         68       34       77  37.6  0.401   24
# 352            3       61         82       28        0  34.4  0.243   46
#
# [537 rows x 8 columns]

# %%
# step5: importing model
from sklearn.linear_model import LogisticRegression    #it uses sigmoid function
model=LogisticRegression(max_iter=500)

# %%
# step6: train model
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
#step7: prediction
Y_pred=model.predict(X_test)

# %%
# step8: accuracy
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.7705627705627706
